# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute  import KNNImputer

# %%
df=sns.load_dataset('titanic')
df=df[['age','embarked','survived']]
df
# Out:
#       age embarked  survived
# 0    22.0        S         0
# 1    38.0        C         1
# 2    26.0        S         1
# 3    35.0        S         1
# 4    35.0        S         0
# ..    ...      ...       ...
# 886  27.0        S         0
# 887  19.0        S         1
# 888   NaN        S         0
# 889  26.0        C         1
# 890  32.0        Q         0
#
# [891 rows x 3 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:1],df.iloc[:,-1],test_size=0.3)

imputer=KNNImputer(n_neighbors=3,weights='uniform')
X_train_trs=imputer.fit_transform(X_train)
X_test_trs=imputer.transform(X_test)

num_new_df = pd.DataFrame(X_train_trs, columns=X_train.columns)

# %%
sns.kdeplot(df['age'])
sns.kdeplot(num_new_df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>
