# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=sns.load_dataset('titanic')
df=df[['age','survived']]
df.isnull().sum()
# Out:
# age         177
# survived      0
# dtype: int64

# %%
df.shape
# Out:
# (891, 2)

# %%
new_df=df.dropna()

# %%
import matplotlib.pyplot as plt

fig=plt.figure()
ax=fig.add_subplot(111)

df['age'].plot.density(ax=ax,color='black')
new_df['age'].plot.density(ax=ax,color='red')
# Out:
# <Axes: ylabel='Density'>
