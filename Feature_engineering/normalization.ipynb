# %% [markdown]
# <h3>normalization techniques</h3>
#
# ->MinMaxScaler<br>
# ->MaxAbsScaler<br>
# ->RobustScaler<br>

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df=sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#


from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

X=df.iloc[:,2:6]
y=df.iloc[:,-1]

X_train ,X_test, y_train,y_test=train_test_split(X,y,test_size=0.3)

sd=RobustScaler()

X_train_scaled=sd.fit_transform(X_train)
X_test_scaled=sd.transform(X_test)


df_train_new=pd.DataFrame(X_train_scaled,columns=[X_train.columns])
df_test_new=pd.DataFrame(X_test_scaled,columns=[X_test.columns])
df_new=pd.concat([df_train_new,df_test_new],axis=0)
df_new
# Out:
#     bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 0        -0.928382      1.112903          0.045455    0.347826
# 1        -0.716180      0.048387         -0.545455   -0.260870
# 2        -0.238727      0.306452         -0.363636   -0.586957
# 3         0.228117     -0.854839          1.045455    0.869565
# 4        -0.461538      0.338710         -0.545455   -0.304348
# ..             ...           ...               ...         ...
# 99       -0.726790      0.112903         -0.681818   -0.739130
# 100       0.164456     -1.241935          0.681818    0.652174
# 101       0.259947      0.403226          0.000000    0.130435
# 102       0.620690      0.177419         -0.090909    0.347826
# 103       1.066313     -0.596774          1.000000    1.304348
#
# [344 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train['bill_length_mm'],X_train['bill_depth_mm'])

# %%
plt.scatter(df_train_new['bill_length_mm'],df_train_new['bill_depth_mm'])
