# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=df[['class','sex','embarked','alone','alive']]
df
# Out:
#       class     sex embarked  alone alive
# 0     Third    male        S  False    no
# 1     First  female        C  False   yes
# 2     Third  female        S   True   yes
# 3     First  female        S  False   yes
# 4     Third    male        S   True    no
# ..      ...     ...      ...    ...   ...
# 886  Second    male        S   True    no
# 887   First  female        S   True   yes
# 888   Third  female        S  False    no
# 889   First    male        C   True   yes
# 890   Third    male        Q   True    no
#
# [891 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# class       0
# sex         0
# embarked    2
# alone       0
# alive       0
# dtype: int64

# %%
df['embarked'].value_counts().sum
# Out:
# <bound method Series.sum of embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64>

# %%
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.3)

# %%
X_train
# Out:
#       class     sex embarked  alone
# 42    Third    male        C   True
# 358   Third  female        Q   True
# 134  Second    male        S   True
# 699   Third    male        S   True
# 544   First    male        C  False
# ..      ...     ...      ...    ...
# 601   Third    male        S   True
# 888   Third  female        S  False
# 128   Third  female        C  False
# 188   Third    male        Q  False
# 828   Third    male        Q   True
#
# [623 rows x 4 columns]

# %%
tfm=ColumnTransformer(transformers=[
    ('embarked_fill',SimpleImputer(strategy='most_frequent'),[2]),

    ],remainder='passthrough')

# %%
yak=tfm.fit_transform(X_train)
dt=pd.DataFrame(yak)
dt[0].isnull().sum()
# Out:
# np.int64(0)

# %%
y_train
# Out:
# 42      no
# 358    yes
# 134     no
# 699     no
# 544     no
#       ...
# 601     no
# 888     no
# 128    yes
# 188     no
# 828    yes
# Name: alive, Length: 623, dtype: object

# %%
transform1=ColumnTransformer(transformers=[
    ('embarked_fill',SimpleImputer(strategy='most_frequent'),[2])
     ],remainder='passthrough')

# %%
transform2=ColumnTransformer(transformers=[
    ('class_ohe',OneHotEncoder(categories=[['First','Second','Third']]),[0]),
    ('embarked_ohe', OneHotEncoder(categories=[['S', 'C', 'Q']]),[2])
    ],remainder='passthrough')

# %%
transform3=ColumnTransformer(transformers=[
    ('sex_oe',OrdinalEncoder(handle_unknown='ignore'),[1]),
    ('alone_oe',OrdinalEncoder(handle_unknown='ignore'),[3]),
    ('alive_oe',OrdinalEncoder(handle_unknown='ignore'),[4])       
    ],remainder='passthrough')

# %%
transform4=DecisionTreeClassifier()

# %% [markdown]
# creating pipeline

# %%
pipe=Pipeline([
    ('transform1',transform1),
    ('transform2',transform2),
    ('transform3',transform3),
    ('transform4',transform4),
])

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
pipe.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pipe.fit(X_train,y_train)
#
# File d:\PYTHON\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File d:\PYTHON\Lib\site-packages\sklearn\pipeline.py:469, in Pipeline.fit(self, X, y, **params)
#     426 """Fit the model.
#     427
#     428 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     466     Pipeline with fitted steps.
#     467 """
# ...
